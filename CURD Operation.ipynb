# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express

# %%
import plotly
from plotly import __version__
print(__version__)

import cufflinks as cf
from plotly.offline import download_plotlyjs , init_notebook_mode , plot ,iplot

init_notebook_mode(connected = True)
cf.go_offline()
# Out:
# 5.9.0
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %% [markdown]
# ### LOAD DATASET

# %%
df = pd.read_csv(r"C:\Users\hp\Downloads\supermarket_sales new.csv")

# %%
df1 = df     # to make a copy
df
# Out:
#      Gender   Invoice ID Branch       City Customer type  \
# 0    Female  750-67-8428      A     Yangon        Member
# 1    Female  226-31-3081      C  Naypyitaw        Normal
# 2    Female  355-53-5943      A     Yangon        Member
# 3    Female  315-22-5665      C  Naypyitaw        Normal
# 4    Female  665-32-9167      A     Yangon        Member
# ..      ...          ...    ...        ...           ...
# 995    Male  745-74-0715      A     Yangon        Normal
# 996    Male  690-01-6631      B   Mandalay        Normal
# 997    Male  233-67-5758      C  Naypyitaw        Normal
# 998    Male  727-02-1313      A     Yangon        Member
# 999    Male  347-56-2442      A     Yangon        Normal
#
#                Product line  Unit price  Quantity    Tax 5%
# 0         Health and beauty       74.69         7  261.4150
# 1    Electronic accessories       15.28         5    3.8200
# 2    Electronic accessories       68.84         6   20.6520
# ...

# %%
df.info()         # basic info of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Gender         1000 non-null   object
#  1   Invoice ID     1000 non-null   object
#  2   Branch         1000 non-null   object
#  3   City           1000 non-null   object
#  4   Customer type  1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Tax 5%         1000 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 70.4+ KB

# %%
df.shape    # it shows no of rows and columns
# Out:
# (1000, 9)

# %%
df.columns      # it shows column name
# Out:
# Index(['Gender', 'Invoice ID', 'Branch', 'City', 'Customer type',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%'],
#       dtype='object')

# %% [markdown]
# # Task 1

# %% [markdown]
# ### 1. CRUD Operations on Sales Dataset
#
# Perform CRUD operations on a sales dataset stored in a CSV file. You can choose any Python
# library or tool for database operations or perform them directly on the CSV file. Implement
# the following operations:
#
#
# Create: Insert new records into the dataset.
#
# Read: Retrieve and display specific records from the dataset.
#
# Update: Modify existing records in the dataset.
#
# Delete: Remove specific records from the dataset.

# %%
df.head(10)    # it shows first 10 records
# Out:
#    Gender   Invoice ID Branch       City Customer type  \
# 0  Female  750-67-8428      A     Yangon        Member
# 1  Female  226-31-3081      C  Naypyitaw        Normal
# 2  Female  355-53-5943      A     Yangon        Member
# 3  Female  315-22-5665      C  Naypyitaw        Normal
# 4  Female  665-32-9167      A     Yangon        Member
# 5  Female  692-92-5582      B   Mandalay        Member
# 6  Female  351-62-0822      B   Mandalay        Member
# 7  Female  365-64-0515      A     Yangon        Normal
# 8  Female  829-34-3910      A     Yangon        Normal
# 9  Female  299-46-1805      B   Mandalay        Member
#
#              Product line  Unit price  Quantity    Tax 5%
# 0       Health and beauty       74.69         7  261.4150
# 1  Electronic accessories       15.28         5    3.8200
# 2  Electronic accessories       68.84         6   20.6520
# 3      Home and lifestyle       73.56        10   36.7800
# 4       Health and beauty       36.26         2    3.6260
# ...

# %% [markdown]
# #### CREAT

# %%
 #"""create new records which want to be added in dataset"""
new_records = [
    ['Female','123-45-678','A','New York','Member','Electronic accessories', 65.25,9,25.15],
    ['Male','789-45-456','B','Yangon','Normal','Health and beauty',45.02,5,3.08],
    ['Male','456-89-123','C','Mandalay','Normal','Fashion accessories',85.75,2,11.05]
]

# %%
new_df = pd.DataFrame(new_records,columns=df.columns)   # it create new dataframe of new records

# %%
new_df
# Out:
#    Gender  Invoice ID Branch      City Customer type            Product line  \
# 0  Female  123-45-678      A  New York        Member  Electronic accessories
# 1    Male  789-45-456      B    Yangon        Normal       Health and beauty
# 2    Male  456-89-123      C  Mandalay        Normal     Fashion accessories
#
#    Unit price  Quantity  Tax 5%
# 0       65.25         9   25.15
# 1       45.02         5    3.08
# 2       85.75         2   11.05

# %%
df = pd.concat([df,new_df],ignore_index=True)   # concat is join new df into original dataset

# %%
df.shape
# Out:
# (1003, 9)

# %%
df.tail()   # it shows last 5 records
# Out:
#       Gender   Invoice ID Branch      City Customer type  \
# 998     Male  727-02-1313      A    Yangon        Member
# 999     Male  347-56-2442      A    Yangon        Normal
# 1000  Female   123-45-678      A  New York        Member
# 1001    Male   789-45-456      B    Yangon        Normal
# 1002    Male   456-89-123      C  Mandalay        Normal
#
#                 Product line  Unit price  Quantity  Tax 5%
# 998       Food and beverages       31.84         1   1.592
# 999       Home and lifestyle       65.82         1   3.291
# 1000  Electronic accessories       65.25         9  25.150
# 1001       Health and beauty       45.02         5   3.080
# 1002     Fashion accessories       85.75         2  11.050

# %% [markdown]
# ### READ

# %%
df= df.rename(columns={'Invoice ID':'Invoice_ID'})     #  it is used to rename the column name

# %%
df.tail(5)
# Out:
#       Gender   Invoice_ID Branch      City Customer type  \
# 998     Male  727-02-1313      A    Yangon        Member
# 999     Male  347-56-2442      A    Yangon        Normal
# 1000  Female   123-45-678      A  New York        Member
# 1001    Male   789-45-456      B    Yangon        Normal
# 1002    Male   456-89-123      C  Mandalay        Normal
#
#                 Product line  Unit price  Quantity  Tax 5%
# 998       Food and beverages       31.84         1   1.592
# 999       Home and lifestyle       65.82         1   3.291
# 1000  Electronic accessories       65.25         9  25.150
# 1001       Health and beauty       45.02         5   3.080
# 1002     Fashion accessories       85.75         2  11.050

# %%
#Retrieve and display specific records from the dataset.
def display_data(df ,Invoice_ID):
    """for display a specific record by using unique identifire
        The Invoice_ID of the product that you want to retrieve from the DataFrame."""
    record = df[df["Invoice_ID"] == Invoice_ID]
    print(record)

# %%
display_data(df ,"456-89-123")         # we want to give Invoice ID to def function to display it
# Out:
#      Gender  Invoice_ID Branch      City Customer type         Product line  \
# 1002   Male  456-89-123      C  Mandalay        Normal  Fashion accessories
#
#       Unit price  Quantity  Tax 5%
# 1002       85.75         2   11.05

# %%
def display_data(df ,Invoice_ID):
    record = df[df["Invoice_ID"] == Invoice_ID]
    print(record)

# %%
display_data(df ,"750-67-8428")
# Out:
#    Gender   Invoice_ID Branch    City Customer type       Product line  \
# 0  Female  750-67-8428      A  Yangon        Member  Health and beauty
#
#    Unit price  Quantity   Tax 5%
# 0       74.69         7  261.415

# %% [markdown]
#  ### UPDATE

# %%
df.tail(3)
# Out:
#       Gender  Invoice_ID Branch      City Customer type  \
# 1000  Female  123-45-678      A  New York        Member
# 1001    Male  789-45-456      B    Yangon        Normal
# 1002    Male  456-89-123      C  Mandalay        Normal
#
#                 Product line  Unit price  Quantity  Tax 5%
# 1000  Electronic accessories       65.25         9   25.15
# 1001       Health and beauty       45.02         5    3.08
# 1002     Fashion accessories       85.75         2   11.05

# %%
def updated_record(df, invoice_id, column_name, new_value):
    
    """This function update records based on the Invoice ID.
        # Loc is used to Locate the row(s) in the DataFrame 
             where 'Invoice_ID' matches the given invoice_id."""
    
    df.loc[df['Invoice_ID'] == invoice_id, column_name] = new_value
    return df    # it return updated df2

# %%
updated_record(df,'123-45-678' , 'Branch', 'B')    # call th function
df.tail(3)
# Out:
#       Gender  Invoice_ID Branch      City Customer type  \
# 1000  Female  123-45-678      B  New York        Member
# 1001    Male  789-45-456      B    Yangon        Normal
# 1002    Male  456-89-123      C  Mandalay        Normal
#
#                 Product line  Unit price  Quantity  Tax 5%
# 1000  Electronic accessories       65.25         9   25.15
# 1001       Health and beauty       45.02         5    3.08
# 1002     Fashion accessories       85.75         2   11.05

# %% [markdown]
# ### DELETE:
#
# Remove specific records from the dataset.

# %%
def delete_record(df, Invoice_ID):     # It remove only 1 record by using unique identifier i.e Invoice_ID
    global df1
    df1 = df[df['Invoice_ID'] != Invoice_ID]        #it removes the records of given Invoice id
    return df1

# %%
delete_record(df, '789-45-456')
df1.tail(3)
# Out:
#       Gender   Invoice_ID Branch      City Customer type  \
# 999     Male  347-56-2442      A    Yangon        Normal
# 1000  Female   123-45-678      B  New York        Member
# 1002    Male   456-89-123      C  Mandalay        Normal
#
#                 Product line  Unit price  Quantity  Tax 5%
# 999       Home and lifestyle       65.82         1   3.291
# 1000  Electronic accessories       65.25         9  25.150
# 1002     Fashion accessories       85.75         2  11.050

# %%
def delete_record(df,column, value):        # It remove multiple records on the basis of value which we are given
    global df2                                # golbal the dataframe for using dataframe out of the code
    df2 = df[df[column] != value]          # it create new dataframe contain records other than specific value which 
                                                             #we given in def function
    return df2

# %%
delete_record(df,'Branch', 'A')      # it will remove all records where branch is 'A'
# Out:
#       Gender   Invoice_ID Branch       City Customer type  \
# 1     Female  226-31-3081      C  Naypyitaw        Normal
# 3     Female  315-22-5665      C  Naypyitaw        Normal
# 5     Female  692-92-5582      B   Mandalay        Member
# 6     Female  351-62-0822      B   Mandalay        Member
# 9     Female  299-46-1805      B   Mandalay        Member
# ...      ...          ...    ...        ...           ...
# 996     Male  690-01-6631      B   Mandalay        Normal
# 997     Male  233-67-5758      C  Naypyitaw        Normal
# 1000  Female   123-45-678      B   New York        Member
# 1001    Male   789-45-456      B     Yangon        Normal
# 1002    Male   456-89-123      C   Mandalay        Normal
#
#                 Product line  Unit price  Quantity   Tax 5%
# 1     Electronic accessories       15.28         5   3.8200
# 3         Home and lifestyle       73.56        10  36.7800
# 5         Food and beverages       54.84         3   8.2260
# ...
